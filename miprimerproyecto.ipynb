# %% [markdown]
# <a href="https://colab.research.google.com/github/David2689/ProgralII-Semi-2026/blob/main/miprimerproyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "hola chicos de progra III"
print(saludo, "primera letra del saludo", saludo[0:4])

num1 = 5.25
print(num1)

booleano = True
print(boleano)
# Out:
# hola chicos de progra III primera letra del saludo hola

# %%
print("sumar dos numeros: " )
num1 = input("Num 1: " )
num2 = input("Num 2: " )
respuesta = float(num1) + float(num2)
print(type(num1), type(num2), type(respuesta))

print("Respuesta: ", respuesta)
respuesta = "suma completa"
print(respuesta, type(respuesta))
# Out:
# sumar dos numeros:
# Num 1: 6
# Num 2: 8
# Respuesta:  14.0

# %%
print("restar dos numeros")
num1 = input("Num1: " )
num2 = input("Num2: " )
respuesta = float(num1) - float(num2)

print("Respuesta: ", respuesta)
# Out:
# restar dos numeros
# Num1: 10
# Num2: 5
# Respuesta:  5.0

# %%
print("multiplicar dos numeros")
num1 = input("Num1: " )
num2 = input("Num2: " )
respuesta = float(num1) * float(num2)

print("Respuesta: ", respuesta)
# Out:
# multiplicar dos numeros
# Num1: 5
# Num2: 5
# Respuesta:  25.0

# %%
print("dividir dos numeros")
num1 = input("Num1: " )
num2 = input("Num2: " )
respuesta = float(num1) / float(num2)

print("Respuesta: ", respuesta)
# Out:
# dividir dos numeros
# Num1: 10
# Num2: 5
# Respuesta:  2.0

# %%
saludo = "hola chicos de progra"
print(saludo, "primera letra del saludo", saludo[0])
print(saludo, "rango en una cadena", saludo[0:4])
print(saludo, "ultimo elemento", saludo[-1])
print(saludo, "ultimo elemento", saludo[len(saludo)-1])
print(saludo, "valores en medio, sin especificar ultimo valor", saludo[5:])
print(saludo, "sin valor al inicio", saludo[:4])
print(saludo, "contar del final", saludo[6:-1])
# Out:
# hola chicos de progra primera letra del saludo h
# hola chicos de progra rango en una cadena hola
# hola chicos de progra ultimo elemento a
# hola chicos de progra ultimo elemento a
# hola chicos de progra valores en medio, sin especificar ultimo valor chicos de progra
# hola chicos de progra sin valor al inicio hola
# hola chicos de progra contar del final hicos de progr

# %%
# Función para convertir Fahrenheit a Celsius
def fahrenheit_a_celsius(fahrenheit):
    celsius = (fahrenheit - 32) * 5 / 9
    return celsius
fahrenheit = float(input("Ingrese la temperatura en grados Fahrenheit: "))

celsius = fahrenheit_a_celsius(fahrenheit)

print("La temperatura en Celsius es:", celsius, "°C")
# Out:
# Ingrese la temperatura en grados Fahrenheit: 98.6
# La temperatura en Celsius es: 37.0 °C

# %%
def convertirKelvin(c):
    return float(c) + 273.15


c = input("C: ")

print("Grados Kelvin:", convertirKelvin(c))
# Out:
# C: 98.6
# Grados Kelvin: 371.75

# %% [markdown]
# tarea de programacion III hcer los sigueintes ejercicios en python haciendo uso de funciones anonimas:
# * farenheit a celcius
# * celcius a kelvin
# * calcular el sueldo de un empleado. hrs * valor de horas * 30 dias
# las deducciones: ISSS, AFP, ISR (ver tabla del mh)
# * elevar un numero a su exponente

# %% [markdown]
# 1. Fahrenheit a Celsius

# %%
converFac = lambda f: (float(f) - 32) * 5 / 9

f = input("F: ")

print("Grados Celsius:", converFac(f))
# Out:
# F: 91.4
# Grados Celsius: 33.0

# %% [markdown]
# 2. Celsius a Kelvin

# %%
converKel = lambda c: float(c) + 273.15

c = input("C: ")

print("Grados Kelvin:", converKel(c))
# Out:
# C: 91.4
# Grados Kelvin: 364.54999999999995

# %% [markdown]
# 3. Calcular el sueldo de un empleado

# %%
sueldo = lambda h, vh: float(h) * float(vh) * 30

horas = input("Horas trabajadas por día: ")
valor = input("Valor por hora: ")

total = sueldo(horas, valor)

isss = total * 0.03
afp = total * 0.0725
isr = total * 0.10

neto = total - isss - afp - isr

print("Sueldo Bruto: $", total)
print("ISSS: $", isss)
print("AFP: $", afp)
print("ISR: $", isr)
print("Sueldo Neto: $", neto)
# Out:
# Horas trabajadas por día: 8
# Valor por hora: 3
# Sueldo Bruto: $ 720.0
# ISSS: $ 21.599999999999998
# AFP: $ 52.199999999999996
# ISR: $ 72.0
# Sueldo Neto: $ 574.1999999999999

# %% [markdown]
# 4. Elevar un número a su exponente

# %%
potencia = lambda n, e: float(n) ** float(e)

numero = input("Número: ")
exponente = input("Exponente: ")

print("Resultado:", potencia(numero, exponente))
# Out:
# Número: 5
# Exponente: 3
# Resultado: 125.0

# %% [markdown]
# Diccionario Json

# %%
persona = {
    "codigo": "USSS001825",
    "nombre": "David Roberto",
    "materias": [
        {
            "codigo": 611,
            "nombre": "Progra I",
            "notas": {
                "C1": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C2": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C3": {"lab1": 8, "lab2": 9, "lab3": 10}
            }
        },
        {
            "codigo": 612,
            "nombre": "Progra II",
            "notas": {
                "C1": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C2": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C3": {"lab1": 8, "lab2": 9, "lab3": 10}
            }
        }
    ]
}

# %%
print(persona["nombre"], "materias: ", persona["materias"][1]["nombre"])
print(persona["materias"][0]["notas"]["C1"]["lab1"])
# Out:
# David Roberto materias:  matematica II
# 8

# %%
persona = {
    "codigo": "USSS001825",
    "nombre": "David Roberto",
    "materias": [
        {
            "codigo": 611,
            "nombre": "matematica I",
            "notas": {
                "C1": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C2": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C3": {"lab1": 8, "lab2": 9, "lab3": 10}
            }
        },
        {
            "codigo": 612,
            "nombre": "matematica II",
            "notas": {
                "C1": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C2": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C3": {"lab1": 8, "lab2": 9, "lab3": 10}
            }
        },{
            "codigo": 613,
            "nombre": "progra",
            "notas": {
                "C1": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C2": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C3": {"lab1": 8, "lab2": 9, "lab3": 10}
            }
        },{
            "codigo": 614,
            "nombre": "base de datos",
            "notas": {
                "C1": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C2": {"lab1": 8, "lab2": 9, "lab3": 10},
                "C3": {"lab1": 8, "lab2": 9, "lab3": 10}
            }
        }
    ]
}

# %%
print(persona["nombre"], "materias: ", persona["materias"][0]["nombre"])
# Out:
# David Roberto materias:  matematica I

# %% [markdown]
# Ejercicio encontrar la nota final de cada materia, haciendo uso de finciones.

# %%
def calcular_nota_materia(materia):
    c1 = (materia["notas"]["C1"]["lab1"] + materia["notas"]["C1"]["lab2"] + materia["notas"]["C1"]["lab3"]) / 3
    c2 = (materia["notas"]["C2"]["lab1"] + materia["notas"]["C2"]["lab2"] + materia["notas"]["C2"]["lab3"]) / 3
    c3 = (materia["notas"]["C3"]["lab1"] + materia["notas"]["C3"]["lab2"] + materia["notas"]["C3"]["lab3"]) / 3

    nota_final = (c1 + c2 + c3) / 3
    return nota_final


print(f"Estudiante: {persona['nombre']}\n" + "-" * 30)

for una_materia in persona["materias"]:
    resultado = calcular_nota_materia(una_materia)
    print("Materia:", una_materia["nombre"])
    print("Nota Final:", round(resultado, 2))
    print("-" * 30)
# Out:
# Estudiante: David Roberto
# ------------------------------
# Materia: matematica I
# Nota Final: 9.0
# ------------------------------
# Materia: matematica II
# Nota Final: 9.0
# ------------------------------
# Materia: progra
# Nota Final: 9.0
# ------------------------------
# Materia: base de datos
# Nota Final: 9.0
# ------------------------------

# %%
#If
#hacer un ejercicio en python que perite clasificar la edad,
#ingrese un balor incorrecto
seguir = True

while seguir:
    edad = int(input("Edad: "))

    if edad < 0:
        seguir = False
        print("Edad incorrecta")
    elif edad < 2:
        print("Eres un bebe")
    elif edad < 11:
        print("Eres un niño")
    elif edad < 18:
        print("Eres un adolescente")
    elif edad < 65:
        print("Eres un adulto")
    elif edad < 85:
        print("Eres un adulto mayor")
    elif edad < 130:
        print("Larga vida")
    else:
        print("Edad incorrecta")
        seguir = False
# Out:
# Edad: 5
# Eres un niño
# Edad: 12
# Eres un adolescente
# Edad: 20
# Eres un adulto
# Edad: 60
# Eres un adulto
# Edad: 130
# Edad incorrecta

# %%
#for
#hacer un ejercicio en python que genere las tablas de multiplicar hasta
#que el usuario decida salir
continuar = True

while continuar:
    ntabla = int(input("Tabla: "))
    for i in range(1, 11):
        print(ntabla, "X", i, "=", i * ntabla)
    respuesta = input("¿Continuar? (Presiona 's' para seguir, o cualquier otra tecla para salir): ")
    if respuesta.lower() != 's':
        continuar = False
# Out:
# Tabla: 4
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# 4 X 10 = 40
# ¿Continuar? (Presiona 's' para seguir, o cualquier otra tecla para salir): s
# Tabla: 5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50
# ¿Continuar? (Presiona 's' para seguir, o cualquier otra tecla para salir): s
# Tabla: 9
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81
# 9 X 10 = 90
# ¿Continuar? (Presiona 's' para seguir, o cualquier otra tecla para salir): f

# %%
#haciendo uso de las estructuras de control, determinar si un numero introducido
#por el usuario es par, impar o primo.
continuar = True

while continuar:
    numero = int(input("Introduce un número entero: "))
    if numero % 2 == 0:
        print(f"El número {numero} es PAR.")
    else:
        print(f"El número {numero} es IMPAR.")
    if numero <= 1:
        print(f"El número {numero} NO es primo (deben ser mayores a 1).")
    else:
        es_primo = True
        for i in range(2, numero):
            if numero % i == 0:
                es_primo = False
                break
        if es_primo:
            print(f"El número {numero} es PRIMO.")
        else:
            print(f"El número {numero} NO es primo.")
    print("-" * 30)
    respuesta = input("¿Deseas evaluar otro número? (Presiona 's' para seguir, o cualquier otra tecla para salir): ")

    if respuesta.lower() != 's':
        continuar = False
        print("¡Hasta luego!")
# Out:
# Introduce un número entero: 2
# El número 2 es PAR.
# El número 2 es PRIMO.
# ------------------------------
# ¿Deseas evaluar otro número? (Presiona 's' para seguir, o cualquier otra tecla para salir): d
# ¡Hasta luego!

# %%
#haciendo uso de las estructuras de control, determinar si un numero introducido
#por el usuario es par, impar o primo.
numero = int(input("Introduce un número entero: "))
if numero % 2 == 0:
    print(f"El número {numero} es PAR.")
else:
    print(f"El número {numero} es IMPAR.")
if numero <= 1:
    print(f"El número {numero} NO es primo (los números primos deben ser mayores a 1).")
else:
    es_primo = True
    for i in range(2, numero):
        if numero % i == 0:
            es_primo = False
            break
    if es_primo:
        print(f"El número {numero} es PRIMO.")
    else:
        print(f"El número {numero} NO es primo.")
# Out:
# Introduce un número entero: 2
# El número 2 es PAR.
# El número 2 es PRIMO.
